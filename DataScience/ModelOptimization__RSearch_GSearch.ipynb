# %%
# Hyperparameter Tunning Method 

# Grid Search CV

# %%
import pandas as pd 
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV,train_test_split

# %%
df=pd.read_csv('Data/Iris.csv')
df.head()
# Out:
#    Id  sepal-length  sepal-width  petal-length  petal-width       target
# 0   1           5.1          3.5           1.4          0.2  Iris-setosa
# 1   2           4.9          3.0           1.4          0.2  Iris-setosa
# 2   3           4.7          3.2           1.3          0.2  Iris-setosa
# 3   4           4.6          3.1           1.5          0.2  Iris-setosa
# 4   5           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            150 non-null    int64
#  1   sepal-length  150 non-null    float64
#  2   sepal-width   150 non-null    float64
#  3   petal-length  150 non-null    float64
#  4   petal-width   150 non-null    float64
#  5   target        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Id  sepal-length  sepal-width  petal-length  petal-width          target
# 0      1           5.1          3.5           1.4          0.2     Iris-setosa
# 1      2           4.9          3.0           1.4          0.2     Iris-setosa
# 2      3           4.7          3.2           1.3          0.2     Iris-setosa
# 3      4           4.6          3.1           1.5          0.2     Iris-setosa
# 4      5           5.0          3.6           1.4          0.2     Iris-setosa
# ..   ...           ...          ...           ...          ...             ...
# 145  146           6.7          3.0           5.2          2.3  Iris-virginica
# 146  147           6.3          2.5           5.0          1.9  Iris-virginica
# 147  148           6.5          3.0           5.2          2.0  Iris-virginica
# 148  149           6.2          3.4           5.4          2.3  Iris-virginica
# ...

# %%
df.columns
# Out:
# Index(['Id', 'sepal-length', 'sepal-width', 'petal-length', 'petal-width',
#        'target'],
#       dtype='object')

# %%
x=df[['sepal-length', 'sepal-width', 'petal-length', 'petal-width']]
y=df['target']

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
param_list={"n_estimators":[100,200,300], "max_depth":[5,8]}
model=RandomForestClassifier()

# %%
grid_search=GridSearchCV(estimator=model,param_grid=param_list,scoring="accuracy")

# %%
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [5, 8], 'n_estimators': [100, 200, 300]},
#              scoring='accuracy')

# %%
print(grid_search.best_params_)
# Out:
# {'max_depth': 8, 'n_estimators': 100}

# %%
print(grid_search.best_score_)
# Out:
# 0.95

# %%
print(grid_search.best_estimator_)
# Out:
# RandomForestClassifier(max_depth=8)

# %%
y_pred=grid_search.predict(X_test)
y_pred
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa'],
#       dtype=object)

# %%
# RandomizedSearchCV

# %%
param_list1={"n_estimators":[100,200,300,500,800], "max_depth":[5,8,10,15],"min_samples_split":[2,3,4,5,6]}
rf=RandomForestClassifier()

# %%
#radom_cv1=RandomizedSearchCV(estimator=rf,param_distributions=param_list1,scoring="accuracy")

# %%
random_cv1 = RandomizedSearchCV(
    estimator=rf,
    param_distributions=param_list1,
    #n_iter=10,
    #cv=5,
    scoring='accuracy',
    #random_state=42
)

# %%
random_cv1.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(estimator=RandomForestClassifier(),
#                    param_distributions={'max_depth': [5, 8, 10, 15],
#                                         'min_samples_split': [2, 3, 4, 5, 6],
#                                         'n_estimators': [100, 200, 300, 500,
#                                                          800]},
#                    scoring='accuracy')

# %%
ypred1=random_cv1.predict(X_test)
ypred1
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa'],
#       dtype=object)

# %%
print(random_cv1.best_params_)
# Out:
# {'n_estimators': 300, 'min_samples_split': 6, 'max_depth': 10}

# %%
print(random_cv1.best_estimator_)
# Out:
# RandomForestClassifier(max_depth=10, min_samples_split=6, n_estimators=300)

# %%
print(random_cv1.best_score_)
# Out:
# 0.9583333333333333
