# %%
import scrapy
from scrapy.crawler import CrawlerRunner

# %%
import crochet
crochet.setup

# %%
class BookSpider(scrapy.Spider): 
    name='BookSpider'
    start_urls=[
        'http://books.toscrape.com/page/1.html', 
        'http://books.toscrape.com/page/2.html', 
        'http://books.toscrape.com/page/3.html']
    
    def start_requests(self):   
        return [scrapy.Request(url=url,callback=self.parse) for url in urls]
    
    def parse(self,response): 
        book_list=response.css('article.product_pod>h3>a::attr(title)').getall()
        
        for i in book_list:
            print(i)

# %%
from scrapy.crawler import CrawlerRunner
from scrapy.utils.project import get_project_settings

custom_settings = {
    'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'
}

process = CrawlerRunner(settings=custom_settings)

# %%
from twisted.internet import reactor
reactor.run()

# %% [markdown]
# # Open Cv for Image

# %%
import cv2

img=cv2.imread("image.jpg",1)
img_1=cv2.imread("image2.jpg",0)
print(type(img_1))
print(img_1)
print(img_1.shape)

# %%
cv2.imshow('image2',img_1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2

img_1 = cv2.imread("image2.jpg", 0)
resized_img = cv2.resize(img_1, (650, 500))

cv2.imshow("image2", resized_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Face detection

# %%
import cv2

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
img = cv2.imread("Photo.JPG")
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray_img, scaleFactor=1.05, minNeighbors=5)

#print(type(faces))
#print(faces)

for x,y,w,h in faces: 
    img=cv2.rectangle(img,(x,y),(x+w , y+h),(0,255,0),3)

resized=cv2.resize(img, (int(img.shape[1]/7),int(img.shape[1]/7)))
cv2.imshow("Gray",resized)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2,time

video=cv2.VideoCapture(0)
check,frame=video.read()

time.sleep(3)
cv2.imshow('Capturing',frame)
cv2.waitKey() 

video.release()
cv2.destroyAllWindows()
