# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import math

original_df=sns.load_dataset('titanic',index_col=False)
#print(original_df.isnull().sum())
age_wrangled_df=original_df[pd.notnull(original_df['age'])]
print(f'# of passenger in age warangled data {str(len(age_wrangled_df))}')

embark_wrangled_df=age_wrangled_df[pd.notnull(age_wrangled_df['embarked'])]
print(f'# of passwnger in embark waragled data {str(len(embark_wrangled_df))}')
embark_wrangled_df
#gender_data=embark_wrangled_df.groupby('sex',as_index=False).reset_index()
#gender_data
#gender_mean_data=gender_data.mean()
#gender_counts_df = embark_wrangled_df.groupby('sex').size().reset_index(name='count')
#age_wrangled_dfgender_mean_data = gender_data.mean()

print(f'Total Survival Rate {embark_wrangled_df['survived'].mean()}')
print('Gender MEan Data')
print(gender_data[['sex','survived','age','pclass','sibsp']])
# Out:
# # of passenger in age warangled data 714
# # of passwnger in embark waragled data 712
# Total Survival Rate 0.4044943820224719
# Gender MEan Data
# ...
