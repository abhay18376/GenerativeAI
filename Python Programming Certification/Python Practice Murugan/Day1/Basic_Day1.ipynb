# %%
print('Welcome to Python Programming')
# Out:
# Welcome to Python Programming

# %% [markdown]
# # Basic of Python Synthax Rule
# 1. Python is case sensetive Language Hello is different fron hello
# 2. Python Do not have command terminator
#    no semicolon is required after statement
#    if you are using multiple statement then only semicolon is used 1+22;2+3;4+5
# 3. Python is Indentation programing Language
# 4. Python is Dynamically Typped programming Language
# 5. # is Single Comment

# %%
#Dynamically Typed Language
x=1
print('Variable Value is ',x)
print('Type of Variable is ', type(x))

x=2.2
print('Value of variable is ',x)
print('Type of variable is ', type(x))

x='My World Python'
print('Value of Variable is ',x)
print('Type of Variable is ',type(x))

# %%
a=10
A=22
print(id(A))
A=22
print(id(A))
B=22
print(id(B))
# Out:
# 140719721688152
# 140719721688152
# 140719721688152

# %% [markdown]
# # Python DataTyped
#                                             Standard Data Types
#                         IMMuttable                                        Mutable
#         Numeric   String   Tuple                                  List    Dictionary    Set

# %%
name = 'Edureka'
print(name)
print(name[2])

# %%
lst=[1,2,3,'Abhay']
print(lst)
lst[3]='aaa'
print(lst)
lst[3]=1111
print(lst)

# %% [raw]
# """  Variable Name Standard
# 1. variable name can have aplhabet, number and underscore
# 2. variable name can start with alphabet or underscore
# 3. variable cannot start with number
# 4. it is case sensitive
# """

# %%
name_122=2
_xyz=2
name='abhay'
Name='Ashok'

# %%
name=input('Enter the name')
print('Name is ', name)
name

# %%
num=input('Enter the number between 1-10')
x=int(num)
print(type(x))
# Out:
# Enter the number between 1-10 5
# <class 'int'>

# %%
"""
Operator in 

Arthmetic Operator :  +,-,*,/
Comparission operator :  <,>,<=,>=
Bitwise Operator :  &,|,>>,<<,~
MemberShip :  In , Not In 
Assignment Operator :  = +=,-=,*=,/=
Logical : and or
Identity : is is not
"""

# %%
a=10  #Arthimetic
b=3
print(a + b)
print(a / b)
print(a * b)
print(a % b) #reminde
print(a//b) #whole
# Out:
# 13
# 3.3333333333333335
# 30
# 1
# 3

# %%
a=12  # Comparison
b=10
print(a>b)
print(a<b)
print(a<=b)
# Out:
# True
# False
# False

# %%
#Assingment
a=10
a+=10
print(a)
# Out:
# 20

# %%
# Logicala
(10==10) and (20<10)
# Out:
# False

# %%
(10==10) and (30>10)
# Out:
# True
