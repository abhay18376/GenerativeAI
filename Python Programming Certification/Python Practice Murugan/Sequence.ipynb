# %%
"""
Type of Sequence 
1. List : created using [] itre are seperated by comma it is muttable can be added and delete
2. Tuple : Tuple greated using () item comma seperates immuttable and faster yo acess
3. Dictionary : it is key value pair created using {} and key valueseperated by :
4. Set is collection of mutable collection of unordered and unique item.

"""

# %%
lst=[1,22,33,44,'Abhay',11.33]
lst.insert(2,"Orange")
lst
lst[-1]
# Out:
# 11.33

# %%
lst[2]
# Out:
# 33

# %%
lst[4]
# Out:
# 'Abhay'

# %%
lst.append('AAA')

# %%
lst
# Out:
# [1, 22, 33, 44, 'Abhay', 11.33, 'AAA']

# %%
lst.extend([14,98,56])

# %%
lst
# Out:
# [1, 22, 33, 44, 'Abhay', 11.33, 'AAA', 14, 98, 56]

# %%
lst.clear()

# %%
lst
lst=[1, 22, 33, 44, 'Abhay', 11.33, 'AAA']

# %%
lst
# Out:
# [1, 22, 33, 44, 'Abhay', 11.33, 'AAA']

# %%
lst.remove(11.33)

# %%
lst
# Out:
# [1, 22, 33, 44, 'Abhay', 'AAA']

# %%
# Slicing
lst[1:5:1]
# Out:
# [22, 33, 44, 'Abhay']

# %%
lst[::-1]
# Out:
# ['AAA', 'Abhay', 44, 33, 22, 1]

# %%
# Tuple
tpl=(1,22,4,55,'abhay',2.33)
tpl
# Out:
# (1, 22, 4, 55, 'abhay', 2.33)

# %%
dir(tuple)

# %%
# Dictiionary
dct={"name":"Krishna","Salary":20000}
dct
# Out:
# {'name': 'Krishna', 'Salary': 20000}

# %%
dir(dict)

# %%
dct["address"]='Mumbai'
dct['Location']=['Mumbai','Pune']
dct["Center"]="Luckhnow"

# %%
dct
# Out:
# {'name': 'Krishna',
#  'Salary': 20000,
#  'address': 'Mumbai',
#  'Location': ['Mumbai', 'Pune'],
#  'Center': 'Luckhnow'}

# %%
#Set
s1={1.1,2,33,4,2,'Abhay',True,2,2,2}
len(s1)
# Out:
# 6

# %%
s1
# Out:
# {1.1, 2, 33, 4, 'Abhay', True}

# %%
s2={22,44,2,'dd'}

# %%
s2
# Out:
# {2, 22, 44, 'dd'}

# %%
s1.intersection(s2)
# Out:
# {2}

# %%
s1.union(s2)
# Out:
# {1.1, 2, 22, 33, 4, 44, 'Abhay', True, 'dd'}

# %%
s1.difference(s2)
# Out:
# {1.1, 33, 4, 'Abhay', True}

# %%
# 1 .Concentation 2. Repitition 3. indexing 4. slicing 5. membership

lst =['asd','Abhay','ashok','Bhalerao']
lst2 =[11,2.33,True,'XYZ']
lstfin=lst + lst2
print(lstfin)  # 1 .Concentation
lstrp =lst * 3
print(lstrp)   #2. Repitition
print(lst[2])  #3. indexing
lsrslc=lst[0:3:]  # 4. slicing
print(lsrslc)
lst3=lstrp[0::2]
lst3
dl=lst[::-1]
dl
# Out:
# ['asd', 'Abhay', 'ashok', 'Bhalerao', 11, 2.33, True, 'XYZ']
# ['asd', 'Abhay', 'ashok', 'Bhalerao', 'asd', 'Abhay', 'ashok', 'Bhalerao', 'asd', 'Abhay', 'ashok', 'Bhalerao']
# ashok
# ['asd', 'Abhay', 'ashok']
# ['Bhalerao', 'ashok', 'Abhay', 'asd']

# %%
lmst=[1,22,33,44,]
lmst.extend(['aa','ss','dd'])
lmst
# Out:
# [1, 22, 33, 44, 'aa', 'ss', 'dd']

# %%
dct_M={"Name":['Abhay','Bhalerao','Ashok'],"Age":[23,34,23],"Salary":[20000,300000,400000]}
dct_M
# Out:
# {'Name': ['Abhay', 'Bhalerao', 'Ashok'],
#  'Age': [23, 34, 23],
#  'Salary': [20000, 300000, 400000]}

# %%
dct_M.get('Name')
# Out:
# ['Abhay', 'Bhalerao', 'Ashok']
