# %%
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd

# %%
hurricanes=pd.read_csv("dataset/Hurricanes.csv")
plt.bar(hurricanes.Year,hurricanes.Hurricanes)
plt.show()

# %%
citytemp=
