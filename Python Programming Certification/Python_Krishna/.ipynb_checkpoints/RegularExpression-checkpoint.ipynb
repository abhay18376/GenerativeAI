# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\ABHAY\\Desktop\\Python_Krishna'

# %%
os.mkdir('testdir')

# %%
os.rename('testdir','test2')

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'class - variable - oop .ipynb',
#  'Exception_and _Inbuiltfunction.ipynb',
#  'File and Function.ipynb',
#  'NewFile.txt',
#  'OOP_Demo.ipynb',
#  'RegularExpression_Numpy.ipynb',
#  'test.txt',
#  'test2']

# %%
import sys  # System python interpreter
class Demo:
    try:
        x= 100/0
    except:
        print('Error is ', sys.exc_info())
# Out:
# Error is  (<class 'ZeroDivisionError'>, ZeroDivisionError('division by zero'), <traceback object at 0x0000026AE614D100>)

# %%
sys.path

# %%
import re
str="Python is super langiuage, Python have it own disadvatage"
re.search('Python',str)
re.findall('Python',str)
# Out:
# ['Python', 'Python']

# %%
re.sub('Python','C',str)
# Out:
# 'C is super langiuage, C have it own disadvatage'

# %%
log="Customer Request received@12:40;11.22.33-Ram"
re.split('[@;-]',log)
# Out:
# ['Customer Request received', '12:40', '11.22.33', 'Ram']

# %%
fp=open('CustomerLog.txt','r')
content=fp.readlines()

fp=open('CustomerLog.txt','r')
for each_line in fp:
    result=re.split('[@;-]',each_line.strip())
    
    print(result[1:])
# Out:
# ['12:50', '110.22.11', 'Ram']
# ['12:40', '11.220.11', 'Ramesh']
# ['13:40', '11.22.101', 'Ramlela']
# ['14:40', '10.22.11', 'Ramla']
# []

# %%
#Package
from DemoPackage import Module
Module.multi_Split('CustomerLog.txt')
# Out:
# [['Customer Request received', '12:50', '110.22.11', 'Ram'],
#  ['Customer Request received', '12:40', '11.220.11', 'Ramesh'],
#  ['Customer Request received', '13:40', '11.22.101', 'Ramlela'],
#  ['Customer Request received', '14:40', '10.22.11', 'Ramla'],
#  ['']]
