# %% [markdown]
# NumPy - Numeric Python
# it deal with only numbers

# %%
# %%timeit
a=range(100000)
b=range(100000)
c=[]
for i in range(len(a)):
    c.append(a[i]*b[i])
# Out:
# 104 ms ± 805 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
import numpy as np
a=np.arange(100000)
b=np.arange(100000)

c= a * b
# Out:
# 802 μs ± 11.2 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
import numpy as np
a=np.array([10,20,30])
a
print(a[0])
print(a[0:2])
print(a.dtype)
print(a.size)
print(a.itemsize)
print(a.shape)
# Out:
# 10
# [10 20]
# int32
# 3
# 4
# (3,)

# %%
a2=np.array([[10,20,30],[40,50,60]])
print(a2.ndim)
print(a2.shape)
print(a2[0][1])
print(a2[0,1])
print(a2[0:2,0:2])
print(a2[0:2,1:3])
# Out:
# 2
# (2, 3)
# 20
# 20
# [[10 20]
#  [40 50]]
# [[20 30]
#  [50 60]]

# %%
ls=[1,2,3,4,5,6,7,8,9]
a2=np.array([[10,20,30,22],[40,50,60,33]])
print(ls[0:3])
print(ls[::-1])
print(a2[0:2,1:3])
# Out:
# [1, 2, 3]
# [9, 8, 7, 6, 5, 4, 3, 2, 1]
# [[20 30]
#  [50 60]]

# %%
for i in np.nditer(a2):
    print(i)
# Out:
# 10
# 20
# 30
# 22
# 40
# 50
# 60
# 33

# %% [markdown]
# '''
# Universal function
# Mathematic operation
# Trignometry operation
# Bit tewdlling operation
# Comparision operation
# '''

# %%
#element by element operation default function
a12=np.array([1,2,3])
a12 * 2
# Out:
# array([2, 4, 6])

# %%
a22=np.array([[11,22,33,44],[55,66,77,88]])
print(a2)
a2 + a22
np.add(a2,a22)
# Out:
# [[10 20 30 22]
#  [40 50 60 33]]
# array([[ 21,  42,  63,  66],
#        [ 95, 116, 137, 121]])

# %%
a2 > a22
# Out:
# array([[False, False, False, False],
#        [False, False, False, False]])

# %%
print(np.sin(a12))
print(np.cos(a12))
print(np.greater(a2,a22))
# Out:
# [0.84147098 0.90929743 0.14112001]
# [ 0.54030231 -0.41614684 -0.9899925 ]
# [[False False False False]
#  [False False False False]]

# %%
np.where(a2==True)
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
a2
# Out:
# array([[10, 20, 30, 22],
#        [40, 50, 60, 33]])

# %%
np.isreal(a12)
# Out:
# array([ True,  True,  True])

# %%
ad=np.array([np.nan,11,44,np.nan,55,66])
np.isnan(ad)
# Out:
# array([ True, False, False,  True, False, False])

# %%
ad
# Out:
# array([nan, 11., 44., nan, 55., 66.])

# %%
a11=np.array([[1,2],[2,3]])
a13=np.array([[2,4],[1,2]])
np.bitwise_or(a11,a13)
# Out:
# array([[3, 6],
#        [3, 3]])

# %%
alog=np.array([[1,2],[3,0]])
np.all(alog)
np.any(alog)
# Out:
# True

# %%
print(ls)
print(np.max(ls))
print(np.sum(ls))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# 9
# 45

# %%
#ravel converting any multi dimenssion array to one dimensiona
a11
# Out:
# array([[1, 2],
#        [2, 3]])

# %%
a11.ravel()
# Out:
# array([1, 2, 2, 3])

# %%
np.shape(a11)
# Out:
# (2, 2)

# %%
np.array_split(ls,2)
# Out:
# [array([1, 2, 3, 4, 5]), array([6, 7, 8, 9])]

# %%
ls
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
print(a13)
np.vsplit(a13,2)
# Out:
# [[2 4]
#  [1 2]]
# [array([[2, 4]]), array([[1, 2]])]

# %%
a13
np.hsplit(a13,2)
# Out:
# [array([[2],
#         [1]]),
#  array([[4],
#         [2]])]

# %%
np.concatenate((a11,a13),axis=0)
# Out:
# array([[1, 2],
#        [2, 3],
#        [2, 4],
#        [1, 2]])

# %%
print(np.stack((a11,a13)))
# Out:
# [[[1 2]
#   [2 3]]
#
#  [[2 4]
#   [1 2]]]

# %%
a13
# Out:
# array([[2, 4],
#        [1, 2]])

# %%
np.vstack((a11,a13))
# Out:
# array([[1, 2],
#        [2, 3],
#        [2, 4],
#        [1, 2]])

# %%
np.save('BinFile',a13)

# %%
a=np.load('BinFile.npy')
a
# Out:
# array([[2, 4],
#        [1, 2]])

# %%
np.savetxt('NumpySave',a11)

# %%
c=np.loadtxt('NumpySave')
c
# Out:
# array([[1., 2.],
#        [2., 3.]])

# %%
np.ones((3,3),dtype=int)
# Out:
# array([[1, 1, 1],
#        [1, 1, 1],
#        [1, 1, 1]])

# %%
np.arange(1,10,2)
# Out:
# array([1, 3, 5, 7, 9])
