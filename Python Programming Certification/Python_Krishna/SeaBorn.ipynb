# %% [markdown]
# 1. Relational : relplot, scatter and line
# 2. Categorical : box , bar , count
# 3. Distribution : histogram, distplot, pair plot,kde
# 4. Matrix : heat map, cluster map

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
sns.relplot(x='sepal_width',y='species',data=iris)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 sns.relplot(x='sepal_width',y='species',data=iris)
#       2 plt.show()
#
# NameError: name 'iris' is not defined

# %%
sns.scatterplot(x='petal_length', y= 'petal_width', data=iris)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sns.scatterplot(x='petal_length', y= 'petal_width', data=iris)
#
# NameError: name 'iris' is not defined

# %%
sns.lineplot(x='species',y='sepal_length', data=iris)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sns.lineplot(x='species',y='sepal_length', data=iris)
#
# NameError: name 'iris' is not defined

# %%
titanic =sns.load_dataset('titanic')
titanic.to_csv('titanic.csv')

# %%
sns.barplot(x='who',y='fare',data=titanic)
plt.show()

# %%
sns.barplot(x='sex',y='fare',hue='who',data=titanic)
plt.show()

# %%
sns.countplot(x='sex',data=titanic)
plt.show()

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.boxplot(x=tips['tip'],data=tips)
# Out:
# <Axes: xlabel='tip'>

# %%
sns.histplot(x='total_bill',data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.pairplot(data=iris)

# %%
sns.pairplot(data=iris,hue='species',diag_kind='hist')

# %%
sns.pairplot(data=iris,hue='species',diag_kind='kde')

# %%
data=np.random.randint(low=1,high=100, size=(10,10))

# %%
data
# Out:
# array([[14, 49, 83, 51, 40, 88, 93, 99,  4, 98],
#        [81, 57, 67, 93,  5, 47, 73, 63,  6, 33],
#        [14, 65,  6, 81, 99, 35, 27,  8, 67, 36],
#        [21, 31,  8, 88,  9, 44, 56, 14, 17, 30],
#        [56, 47, 56, 28, 30,  1, 67, 45, 13, 20],
#        [38, 12, 88, 97, 53, 84, 68, 94, 90, 33],
#        [10, 59, 72, 75, 15,  9, 43, 79, 86, 30],
#        [76, 57,  2,  9, 69, 47, 47,  4, 73, 69],
#        [21, 44, 55, 87,  7, 33, 74, 65, 46, 71],
#        [28, 17, 12, 30, 85, 79, 55, 66, 77, 37]])

# %%
sns.heatmap(data,annot=True)
# Out:
# <Axes: >

# %%
health=sns.load_dataset('healthexp')
health
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 0    1970        Germany       252.311             70.6
# 1    1970         France       192.143             72.2
# 2    1970  Great Britain       123.993             71.9
# 3    1970          Japan       150.437             72.0
# 4    1970            USA       326.961             70.9
# ..    ...            ...           ...              ...
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0
#
# [274 rows x 4 columns]

# %%
corr_data=health[['Spending_USD','Life_Expectancy']].corr()
corr_data
# Out:
#                  Spending_USD  Life_Expectancy
# Spending_USD          1.00000          0.57943
# Life_Expectancy       0.57943          1.00000

# %%
# any value which is more than 0,5 is correlated
sns.heatmap(corr_data,annot=True)
# Out:
# <Axes: >

# %%
flights=sns.load_dataset('flights')
corr_data=flights[['year','passengers']].corr()
corr_data
# Out:
#                 year  passengers
# year        1.000000    0.921824
# passengers  0.921824    1.000000

# %%
sns.heatmap(corr_data,annot=True)
# Out:
# <Axes: >

# %%
sns.lineplot(x='year',y='passengers',data=flights)
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
c_data=tips[['total_bill','tip','size']].corr()
c_data
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(c_data,annot=True)
# Out:
# <Axes: >

# %%
c_data2=sns.load_dataset('car_crashes')
c_dat=c_data2.iloc[:,0:-1].corr()
c_dat
# Out:
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# speeding          -0.077675   -0.065928
# alcohol           -0.170612   -0.112547
# not_distracted    -0.174856   -0.075970
# no_previous       -0.156895   -0.006359
# ins_premium        1.000000    0.623116
# ins_losses         0.623116    1.000000

# %%
sns.heatmap(c_dat,annot=True)
# Out:
# <Axes: >
