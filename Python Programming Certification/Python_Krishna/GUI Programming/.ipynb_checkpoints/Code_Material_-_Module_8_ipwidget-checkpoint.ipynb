# %% [markdown]
# # Some real world use cases are listed here

# %%
! pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (7.7.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets) (3.6.0)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets) (8.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets) (5.3.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets) (5.1.1)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets) (6.12.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets) (1.1.0)
# Requirement already satisfied: packaging in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (21.3)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (7.2.2)
# Requirement already satisfied: nest-asyncio in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.5)
# Requirement already satisfied: tornado>=6.1 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1)
# Requirement already satisfied: psutil in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.0)
# Requirement already satisfied: debugpy>=1.0 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.0)
# Requirement already satisfied: decorator in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets) (5.1.1)
# Requirement already satisfied: backcall in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets) (58.1.0)
# Requirement already satisfied: pickleshare in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets) (2.11.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.18.1)
# Requirement already satisfied: stack-data in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: colorama in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.4.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from ipython>=4.0.0->ipywidgets) (3.0.29)
# Requirement already satisfied: fastjsonschema in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (2.15.3)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (4.4.0)
# Requirement already satisfied: jupyter-core in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (4.9.2)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from widgetsnbextension~=3.6.0->ipywidgets) (6.4.10)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (21.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: pyzmq>=22.3 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (22.3.0)
# Requirement already satisfied: entrypoints in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: pywin32>=1.0 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets) (303)
# Requirement already satisfied: prometheus-client in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.14.1)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.13.3)
# Requirement already satisfied: nbconvert>=5 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.4.5)
# Requirement already satisfied: jinja2 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.1.1)
# Requirement already satisfied: argon2-cffi in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.0)
# Requirement already satisfied: wcwidth in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from packaging->ipykernel>=4.5.1->ipywidgets) (3.0.7)
# Requirement already satisfied: asttokens in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.2.2)
# Requirement already satisfied: executing in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.8.4)
# Requirement already satisfied: bleach in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.0.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.11.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.0)
# Requirement already satisfied: defusedxml in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.1.1)
# Requirement already satisfied: testpath in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.6.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.13)
# Requirement already satisfied: six>=1.5 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (1.16.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.0.5)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.15.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.3.2)
# Requirement already satisfied: webencodings in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\bvvkr\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.21)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\bvvkr\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
#from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from IPython.display import display

# %%
# A simple class rating example

txt = widgets.Text(description = 'Name')
slider1 = widgets.IntSlider(description='ClassRating')
slider2 = widgets.IntSlider(description='InstructorRating')

display(txt, slider1, slider2)
# Out:
# Text(value='', description='Name')
# IntSlider(value=0, description='ClassRating')
# IntSlider(value=0, description='InstructorRating')

# %%
print('Student name', txt.value)
print('Class Rating', slider1.value)
print('Instructor Rating', slider2.value)
# Out:
# Student name Rahul
# Class Rating 14
# Instructor Rating 23

# %%
# A simple class rating example - Advanced way

txt = widgets.Text(description = 'Overall Rating')

slider1 = widgets.IntSlider(description='InstructorRating')

associate_link = widgets.jslink((txt, 'value'), (slider1, 'value'))

display(txt, slider1)
# Out:
# Text(value='', description='Overall Rating')
# IntSlider(value=0, description='InstructorRating')

# %%
slider1.keys
#txt.keys
# Out:
# ['_dom_classes',
#  '_model_module',
#  '_model_module_version',
#  '_model_name',
#  '_view_count',
#  '_view_module',
#  '_view_module_version',
#  '_view_name',
#  'continuous_update',
#  'description',
#  'description_tooltip',
#  'disabled',
#  'layout',
#  'max',
#  'min',
#  'orientation',
#  'readout',
#  'readout_format',
#  'step',
#  'style',
#  'value']

# %%
# Getting the rating score - event driven way

a_intslider = widgets.IntSlider(
value=6, # default value
min=0,
max=20,
step=3,
description='a',
disabled=False,
continuous_update=True,
orientation='vertical',
readout=True,
readout_format="d") # d - int, f = float

def f(a):
    print('Given Rating is:', a)

out = widgets.interactive_output(f, {'a':a_intslider})

widgets.VBox([widgets.VBox([a_intslider]), out])
# Out:
# VBox(children=(VBox(children=(IntSlider(value=6, description='a', max=20, orientation='vertical', step=3),)), …

# %%
# progress bar example
import time 

pg = widgets.IntProgress(description = 'Loading...', orientation = 'horizontal', bar_style = 'warning')
display(pg)

for i in range(0,1000):
    pg.value = i
    time.sleep(0.1)
# Out:
# IntProgress(value=0, bar_style='warning', description='Loading...')

# %%
# A simple Calculator program

from ipywidgets import Button, HBox, VBox, Text
from functools import reduce

words = ['1', '2', '3', '4', '5', '6', '7', '8', '9', '+', '*', '-'] 

items = [Button(description=w) for w in words] 
print(items)

first_row_box = HBox([items[i] for i in range(3)])
second_row_box = HBox([items[i] for i in range(3,6)])
third_row_box = HBox([items[i] for i in range(6, 9)])
fourth_row_box = HBox([items[i] for i in range(9,len(items))])
#print(first_row_box)
text_box = Text(description = 'Result')

layout1 = VBox([first_row_box, third_row_box, second_row_box, fourth_row_box])
layout2 = VBox([text_box])
display(layout1, layout2)


nums = []
def on_button_clicked(b):
    global nums
    
    print(nums)
    if b.description not in ('+', '*', '-'):
        nums.append(int(b.description))
    else:
        if b.description == '+':
            result = sum(nums)
            text_box.value = str(result)
        elif b.description == '*':
            result = reduce((lambda a, b: a * b), nums)
            text_box.value = str(result)
        elif b.description == '-':
            result = reduce((lambda a, b: a - b), nums)
            text_box.value = str(result)
        nums.clear()

for i in range(len(items)):
    items[i].on_click(on_button_clicked)
# Out:
# [Button(description='1', style=ButtonStyle()), Button(description='2', style=ButtonStyle()), Button(description='3', style=ButtonStyle()), Button(description='4', style=ButtonStyle()), Button(description='5', style=ButtonStyle()), Button(description='6', style=ButtonStyle()), Button(description='7', style=ButtonStyle()), Button(description='8', style=ButtonStyle()), Button(description='9', style=ButtonStyle()), Button(description='+', style=ButtonStyle()), Button(description='*', style=ButtonStyle()), Button(description='-', style=ButtonStyle())]
# VBox(children=(HBox(children=(Button(description='1', style=ButtonStyle()), Button(description='2', style=Butt…
# VBox(children=(Text(value='', description='Result'),))
# []
# [7]
# [7, 1]
# [7, 1, 8]
# []
# [5]
# [5, 6]

# %%
play = widgets.Play(
    value=50,
    min=0,
    max=100,
    step=1,
    interval=500,
    description="Press play",
    disabled=False
)
slider = widgets.IntSlider()
widgets.jslink((play, 'value'), (slider, 'value'))
widgets.HBox([play, slider])
# Out:
# HBox(children=(Play(value=50, description='Press play', interval=500), IntSlider(value=0)))

# %%
from functools import reduce 

nums = [1,2,3,4,5]

prod = 1
for i in nums:
    prod *= i
print(prod)

r = reduce((lambda a, b: a * b), nums)
print(r)
# Out:
# 120
# 120

# %%
l_obj = lambda n : n ** 2

# %%
l_obj(10)
# Out:
# 100

# %%
def power(n):
    return n ** 2

# %%
power(10)
# Out:
# 100

# %%
x = [1,2,3,4,1,41,4,2]

# %%
l_obj2 = lambda a, b: a * b

# %%
reduc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 reduc
#
# NameError: name 'reduc' is not defined
