# %% [markdown]
# # ReACT Agent
#
# In this notebook we will look into experimenting with ReACT Agent with Simple Calculator Tools and RAG QueryEngine Tools.

# %%
# !pip install llama-index
# !pip install llama-index-llms-anthropic
# !pip install llama-index-llms-mistralai

# %% [markdown]
# ## Simple Calculator Tools

# %%
from llama_index.core.agent import ReActAgent,AgentWorkflow
from llama_index.llms.openai import OpenAI
from llama_index.core.llms import ChatMessage
from llama_index.core.tools import BaseTool, FunctionTool

# %% [markdown]
# ### Define Tools

# %%
def multiply(a: int, b: int) -> int:
    """Multiply two integers and returns the result integer"""
    return a * b

def add(a: int, b: int) -> int:
    """Add two integers and returns the result integer"""
    return a + b

def subtract(a: int, b: int) -> int:
    """Subtract two integers and returns the result integer"""
    return a - b

# %%
multiply_tool = FunctionTool.from_defaults(fn=multiply)
add_tool = FunctionTool.from_defaults(fn=add)
subtract_tool = FunctionTool.from_defaults(fn=subtract)

# %% [markdown]
# ####  OpenAI GPT-4

# %%
import os
os.environ['OPENAI_API_KEY'] = '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'

# %%
llm = OpenAI(model="gpt-4")
agent = ReActAgent(tools=[multiply_tool, add_tool, subtract_tool], llm=llm, verbose=True)

# %%
#agent = AgentWorkflow([agent_strategy])

# %%
response = agent.run("What is 20+(2*4)? Calculate step by step.")

# %%
print(response.result())
# Out:
# The result of the calculation 20+(2*4) is 28.

# %%
response = agent.run("What is AI")

# %%
print(response.result())
# Out:
# AI, or Artificial Intelligence, refers to the simulation of human intelligence in machines that are programmed to think like humans and mimic their actions. This term is often applied to any machine that exhibits traits associated with a human mind such as learning and problem-solving.
